# %%
import pandas as pd

# %% [markdown]
# # Task1
# * Load a CSV dataset into a Pandas DataFrame.

# %%
df = pd.read_csv("tops.csv")
df
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       NaN  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       NaN    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                NaN
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                  NaN
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                  NaN
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                  NaN
# 120  Plo███o.8███ Se█████████Pha███████████████████...                  NaN
# 121  Fla███o 6███jay█████████s, ███████████████████...                  NaN
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %% [markdown]
# # Task 2
# * Explore data (head/tail, shape, columns, data types)

# %%
df.head(10)
# Out:
#    product_id            title  \
# 0    18614510         Oxolloxo
# 1    18972586          MALHAAR
# 2    18937628  her by invictus
# 3    18972622          MALHAAR
# 4    18979466       KiddoPanti
# 5    18972618          MALHAAR
# 6    18990292      HILL STREET
# 7    18972748      Zink London
# 8    18998738           KALINI
# 9    18904492            Levis
#
#                                  product_description  rating  ratings_count  \
# 0                  Women Blue Crepe Blouson Crop Top     0.0              0
# 1  Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                 Printed A-Line Top     4.2             29
# 3                               Green Print Wrap Top     0.0              0
# 4  White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# 5               Red Print Mandarin Collar Peplum Top     0.0              0
# 6  Women Fluorescent Green Solid Pure Cotton Tank...     4.5             15
# 7                         Yellow Geometric Print Top     4.3              7
# 8   Green & charleston green Animal Print Indigo Top     0.0              0
# 9  Women Sage Green Self Design Slim Fit Regular Top     4.4             50
#
#    initial_price  discount  final_price currency  \
# 0         2299.0      73.0    "₹599.00"      INR
# 1         3329.0      79.0    "₹699.00"      INR
# 2         1398.0      66.0    "₹475.00"      INR
# 3         3329.0      78.0    "₹732.00"      INR
# 4          799.0      46.0    "₹431.00"      INR
# 5         3329.0      79.0    "₹699.00"      INR
# 6         1699.0      65.0    "₹594.00"      INR
# 7         1499.0      65.0    "₹524.00"      INR
# 8         1999.0      74.0    "₹519.00"      INR
# 9         2099.0      20.0  "₹1,133.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/186...  ...
# 1  http://assets.myntassets.com/assets/images/189...  ...
# 2  http://assets.myntassets.com/assets/images/189...  ...
# 3  http://assets.myntassets.com/assets/images/189...  ...
# 4  http://assets.myntassets.com/assets/images/189...  ...
# 5  http://assets.myntassets.com/assets/images/189...  ...
# 6  http://assets.myntassets.com/assets/images/189...  ...
# 7  http://assets.myntassets.com/assets/images/189...  ...
# 8  http://assets.myntassets.com/assets/images/189...  ...
# 9  http://assets.myntassets.com/assets/images/189...  ...
#
#                                      amount_of_stars  \
# 0  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 5  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 6  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 7  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 8  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 9  {"1_star":4,"2_stars":1,"3_stars":2,"4_stars":...
#
#                                  what_customers_said  \
# 0                                                NaN
# 1                                                NaN
# 2  [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                NaN
# 4                                                NaN
# 5  [{"percentage":"100","value_name":"Fit, Just R...
# 6  [{"percentage":"100","value_name":"Fit, Just R...
# 7                                                NaN
# 8                                                NaN
# 9  [{"percentage":"67","value_name":"Fit, Just Ri...
#
#                                   seller_name  \
# 0  M/S███PA ███ARE█████████E L███████████████
# 1                       BED███E S███IES██████
# 2                                Sup███om ███
# 3                       BED███E S███IES██████
# 4           Kri███n A███rel█████████Lim██████
# 5                       BED███E S███IES██████
# 6                    HIL███TRE███LIF█████████
# 7              FRE███ GL███L P█████████MIT███
# 8                          Oma███Ent███ris███
# 9                  Lev███tra███ In█████████td
#
#                                                sizes  \
# 0  [{"size":"S","value":"34.0in","value_name":"To...
# 1  [{"size":"S","value":"35.0in","value_name":"To...
# 2  [{"size":"S","value":"34.0in","value_name":"To...
# 3  [{"size":"XS","value":"33.0in","value_name":"T...
# 4  [{"size":"2-3Y","value":"14.8in","value_name":...
# 5  [{"size":"XS","value":"33.0in","value_name":"T...
# 6  [{"size":"S","value":"34.0in","value_name":"To...
# 7  [{"size":"XS","value":"32.0in","value_name":"T...
# 8  [{"size":"XS","value":"34.0in","value_name":"B...
# 9  [{"size":"XS","value":"37.5in","value_name":"B...
#
#                                               videos  \
# 0                                                NaN
# 1                                                NaN
# 2  ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  ["https://videos.myntassets.com/assets/videos/...
#
#                                   seller_information           variations  \
# 0  C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1  1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2  Plo███o- ███ 1s█████████Sui███████████████████...                  NaN
# 3  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4  Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# 5  1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 6  50,███OCK███ AS█████████PHA███████████████████...                  NaN
# 7  148███49,███0 A█████████lla███████████████████...                  NaN
# 8  PAR███NAT███ARA█████████ PL███████████████████...        [{},{},{},{}]
# 9  Eco███xpr███ Pv█████████no ███████████████████...                  NaN
#
#                                           best_offer  \
# 0  {"applicable_on":"Orders above Rs. 649 (only o...
# 1  {"applicable_on":"Orders above Rs. 999 (only o...
# 2  {"applicable_on":"Orders above Rs. 649 (only o...
# 3  {"applicable_on":"Orders above Rs. 999 (only o...
# 4  {"applicable_on":"Orders above Rs. 649 (only o...
# 5  {"applicable_on":"Orders above Rs. 999 (only o...
# 6  {"applicable_on":"Orders above Rs. 649 (only o...
# 7  {"applicable_on":"Orders above Rs. 649 (only o...
# 8  {"applicable_on":"Orders above Rs. 649 (only o...
# 9  {"applicable_on":"Orders above Rs. 1099 (only ...
#
#                                          more_offers category
# 0  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 5  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 6  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 7  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 8  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 9  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [10 rows x 24 columns]

# %%
df.tail(10)
# Out:
#      product_id            title  \
# 112    11878498       DODO & MOA
# 113     7326508             MISH
# 114      586846           Cation
# 115    18000968            Harpa
# 116    18937522  her by invictus
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                product_description  rating  ratings_count  \
# 112        Women Black Solid Top With Lace Inserts     3.9              9
# 113                           Women Pink Solid Top     4.7             25
# 114                                Women Black Top     4.5             11
# 115                 Women Maroon V-Neck Casual Top     4.4             21
# 116                    V-Neck Textured Regular Top     3.9             57
# 117     Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                          Yellow Print Wrap Top     0.0              0
# 119          Women Peach-Coloured Self Checked Top     3.6             35
# 120  High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121      Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 112         1290.0      60.0  "₹1,290.00"      INR
# 113         1499.0      45.0  "₹1,499.00"      INR
# 114          899.0      40.0    "₹899.00"      INR
# 115         1049.0      48.0  "₹1,049.00"      INR
# 116         1298.0      65.0    "₹454.00"      INR
# 117         2495.0       NaN  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       NaN    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 112  http://assets.myntassets.com/assets/images/118...  ...
# 113  http://assets.myntassets.com/assets/images/732...  ...
# 114  http://assets.myntassets.com/v1/images/style/p...  ...
# 115  http://assets.myntassets.com/assets/images/180...  ...
# 116  http://assets.myntassets.com/assets/images/189...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 112  {"1_star":2,"2_stars":0,"3_stars":0,"4_stars":...
# 113  {"1_star":0,"2_stars":1,"3_stars":2,"4_stars":...
# 114  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 115  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 116  {"1_star":7,"2_stars":4,"3_stars":6,"4_stars":...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 112  [{"percentage":"100","value_name":"Fit, Just R...
# 113  [{"percentage":"67","value_name":"Fit, Just Ri...
# 114  [{"percentage":"67","value_name":"Fit, Just Ri...
# 115                                                NaN
# 116  [{"percentage":"67","value_name":"Fit, A Littl...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                NaN
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                     seller_name  \
# 112                         NaN
# 113                         NaN
# 114                         NaN
# 115                         NaN
# 116                Sup███om ███
# 117  Nik███ndi███riv█████████ed
# 118       BED███E S███IES██████
# 119  JAI███MAR███OTH█████████TD
# 120    V-M███ Re███l L█████████
# 121                      Fly███
#
#                                                  sizes  \
# 112  [{"size":"S","value":"34.0in","value_name":"To...
# 113  [{"size":"S","value":"34.0in","value_name":"Bu...
# 114  [{"size":"S","value":"34.0in","value_name":"Bu...
# 115  [{"size":"XS","value":"30.0in","value_name":"T...
# 116  [{"size":"S","value":"34.0in","value_name":"To...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                      videos  \
# 112                     NaN
# 113                     NaN
# 114                     NaN
# 115                     NaN
# 116  ["rw-18937522_cae700"]
# 117  ["rw-18962100_cae700"]
# 118                     NaN
# 119                     NaN
# 120                     NaN
# 121                     NaN
#
#                                     seller_information        variations  \
# 112                                                NaN               NaN
# 113                                                NaN               NaN
# 114                                                NaN               NaN
# 115                                                NaN  [{},{},{},{},{}]
# 116  Plo███o- ███ 1s█████████Sui███████████████████...              [{}]
# 117  Oly███a B███din█████████e T███████████████████...               NaN
# 118  1/4███Rii███Ind█████████rea███████████████████...        [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...               NaN
# 120  Plo███o.8███ Se█████████Pha███████████████████...               NaN
# 121  Fla███o 6███jay█████████s, ███████████████████...               NaN
#
#                                             best_offer  \
# 112                                                 {}
# 113                                                 {}
# 114                                                 {}
# 115                                                 {}
# 116  {"applicable_on":"Orders above Rs. 649 (only o...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 112  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 113  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 114  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 115  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 116  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [10 rows x 24 columns]

# %%
df.describe().T
# Out:
#                count          mean           std       min           25%  \
# product_id     122.0  1.584558e+07  4.719283e+06  586846.0  1.359048e+07
# rating         122.0  3.450000e+00  1.422212e+00       0.0  3.325000e+00
# ratings_count  122.0  4.161475e+01  6.704969e+01       0.0  7.000000e+00
# initial_price  122.0  1.578779e+03  7.533604e+02     329.0  9.990000e+02
# discount       107.0  5.466355e+01  1.775246e+01       5.0  4.550000e+01
#
#                       50%          75%         max
# product_id     17950203.0  18969964.50  22747068.0
# rating                4.0         4.30         5.0
# ratings_count        17.0        49.25       454.0
# initial_price      1499.0      1998.75      3590.0
# discount             60.0        65.00        82.0

# %%
df.describe(include='str').T
# Out:
#                        count unique  \
# title                    122     69
# product_description      122    117
# final_price              122     65
# currency                 122      1
# images                   122    122
# delivery_options         122      4
# product_details          122    122
# breadcrumbs              122     69
# product_specifications   122    122
# amount_of_stars          122    107
# what_customers_said       84     61
# seller_name               39     25
# sizes                    122    107
# videos                    18     18
# seller_information        39     25
# variations                51     13
# best_offer               122     31
# more_offers              122      2
# category                 122      1
#
#                                                                       top freq
# title                                                             MALHAAR    6
# product_description                                  Women Pink Solid Top    3
# final_price                                                   "₹1,499.00"    8
# currency                                                              INR  122
# images                  http://assets.myntassets.com/assets/images/186...    1
# delivery_options        ["100% Original Products","Pay on delivery mig...  113
# product_details         {"description":"  Blue crop blouson top   Soli...    1
# breadcrumbs             [{"name":"Clothing","url":"https://www.myntra....    6
# product_specifications  [{"specification_name":"Body Shape ID","specif...    1
# amount_of_stars         {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...   16
# what_customers_said     [{"percentage":"100","value_name":"Fit, Just R...   14
# seller_name                                         BED███E S███IES██████    6
# sizes                   [{"size":"XXS","value":"30.0in","value_name":"...    4
# videos                  ["rw-18937628_cae700","https://videos.myntasse...    1
# seller_information      1/4███Rii███Ind█████████rea███████████████████...    6
# variations                                                     [{},{},{}]   12
# best_offer                                                             {}   83
# more_offers             [{"offer_name":"10% Instant Discount on Citi C...   84
# category                                                             tops  122

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              122 non-null    int64
#  1   title                   122 non-null    str
#  2   product_description     122 non-null    str
#  3   rating                  122 non-null    float64
#  4   ratings_count           122 non-null    int64
#  5   initial_price           122 non-null    float64
#  6   discount                107 non-null    float64
#  7   final_price             122 non-null    str
#  8   currency                122 non-null    str
#  9   images                  122 non-null    str
#  10  delivery_options        122 non-null    str
#  11  product_details         122 non-null    str
#  12  breadcrumbs             122 non-null    str
#  13  product_specifications  122 non-null    str
#  14  amount_of_stars         122 non-null    str
#  15  what_customers_said     84 non-null     str
#  16  seller_name             39 non-null     str
#  17  sizes                   122 non-null    str
#  18  videos                  18 non-null     str
#  19  seller_information      39 non-null     str
#  20  variations              51 non-null     str
#  21  best_offer              122 non-null    str
#  22  more_offers             122 non-null    str
#  23  category                122 non-null    str
# dtypes: float64(3), int64(2), str(19)
# memory usage: 592.9 KB

# %%
df.shape
# Out:
# (122, 24)

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df[["title","product_description","rating","final_price","delivery_options","discount"]]
# Out:
#                title                                product_description  \
# 0           Oxolloxo                  Women Blue Crepe Blouson Crop Top
# 1            MALHAAR  Yellow & Red Geometric Print Mandarin Collar C...
# 2    her by invictus                                 Printed A-Line Top
# 3            MALHAAR                               Green Print Wrap Top
# 4         KiddoPanti  White & Navy Blue Geometric Print Georgette Sh...
# ..               ...                                                ...
# 117             Nike         Women Black Brand Logo Printed Dri Fit Top
# 118          MALHAAR                              Yellow Print Wrap Top
# 119           Madame              Women Peach-Coloured Self Checked Top
# 120           V-Mart      High Neck Puff Sleeves Gathered Georgette Top
# 121         Friskers          Women Black Solid Organic Cotton Tank Top
#
#      rating  final_price                                   delivery_options  \
# 0       0.0    "₹599.00"  ["100% Original Products","Pay on delivery mig...
# 1       0.0    "₹699.00"  ["100% Original Products","Pay on delivery mig...
# 2       4.2    "₹475.00"  ["100% Original Products","Pay on delivery mig...
# 3       0.0    "₹732.00"  ["100% Original Products","Pay on delivery mig...
# 4       0.0    "₹431.00"  ["100% Original Products","Pay on delivery mig...
# ..      ...          ...                                                ...
# 117     4.4  "₹2,495.00"  ["100% Original Products","Pay on delivery mig...
# 118     0.0    "₹732.00"  ["100% Original Products","Pay on delivery mig...
# 119     3.6    "₹479.00"  ["100% Original Products","Pay on delivery mig...
# 120     3.7    "₹449.00"  ["100% Original Products","Pay on delivery mig...
# 121     0.0    "₹631.00"  ["100% Original Products","Pay on delivery mig...
#
#      discount
# 0        73.0
# 1        79.0
# 2        66.0
# 3        78.0
# 4        46.0
# ..        ...
# 117       NaN
# 118      78.0
# 119      70.0
# 120       NaN
# 121      60.0
#
# [122 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %% [markdown]
# # Task 3
# * Handle missing values (identify, fill/drop)

# %%
df.isnull()
# Out:
#      product_id  title  product_description  rating  ratings_count  \
# 0         False  False                False   False          False
# 1         False  False                False   False          False
# 2         False  False                False   False          False
# 3         False  False                False   False          False
# 4         False  False                False   False          False
# ..          ...    ...                  ...     ...            ...
# 117       False  False                False   False          False
# 118       False  False                False   False          False
# 119       False  False                False   False          False
# 120       False  False                False   False          False
# 121       False  False                False   False          False
#
#      initial_price  discount  final_price  currency  images  ...  \
# 0            False     False        False     False   False  ...
# 1            False     False        False     False   False  ...
# 2            False     False        False     False   False  ...
# 3            False     False        False     False   False  ...
# 4            False     False        False     False   False  ...
# ..             ...       ...          ...       ...     ...  ...
# 117          False      True        False     False   False  ...
# 118          False     False        False     False   False  ...
# 119          False     False        False     False   False  ...
# 120          False      True        False     False   False  ...
# 121          False     False        False     False   False  ...
#
#      amount_of_stars  what_customers_said  seller_name  sizes  videos  \
# 0              False                 True        False  False    True
# 1              False                 True        False  False    True
# 2              False                False        False  False   False
# 3              False                 True        False  False    True
# 4              False                 True        False  False    True
# ..               ...                  ...          ...    ...     ...
# 117            False                False        False  False   False
# 118            False                 True        False  False    True
# 119            False                False        False  False    True
# 120            False                False        False  False    True
# 121            False                False        False  False    True
#
#      seller_information  variations  best_offer  more_offers  category
# 0                 False       False       False        False     False
# 1                 False       False       False        False     False
# 2                 False        True       False        False     False
# 3                 False       False       False        False     False
# 4                 False       False       False        False     False
# ..                  ...         ...         ...          ...       ...
# 117               False        True       False        False     False
# 118               False       False       False        False     False
# 119               False        True       False        False     False
# 120               False        True       False        False     False
# 121               False        True       False        False     False
#
# [122 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                   15
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said        38
# seller_name                83
# sizes                       0
# videos                    104
# seller_information         83
# variations                 71
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %% [markdown]
# * Dropping Missing Values

# %%
df.dropna(axis=0)
# Out:
#      product_id            title          product_description  rating  \
# 116    18937522  her by invictus  V-Neck Textured Regular Top     3.9
#
#      ratings_count  initial_price  discount final_price currency  \
# 116             57         1298.0      65.0   "₹454.00"      INR
#
#                                                 images  ...  \
# 116  http://assets.myntassets.com/assets/images/189...  ...
#
#                                        amount_of_stars  \
# 116  {"1_star":7,"2_stars":4,"3_stars":6,"4_stars":...
#
#                                    what_customers_said   seller_name  \
# 116  [{"percentage":"67","value_name":"Fit, A Littl...  Sup███om ███
#
#                                                  sizes  \
# 116  [{"size":"S","value":"34.0in","value_name":"To...
#
#                      videos  \
# 116  ["rw-18937522_cae700"]
#
#                                     seller_information variations  \
# 116  Plo███o- ███ 1s█████████Sui███████████████████...       [{}]
#
#                                             best_offer  \
# 116  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 116  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [1 rows x 24 columns]

# %%
df.dropna(axis=1)
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  final_price currency  \
# 0           2299.0    "₹599.00"      INR
# 1           3329.0    "₹699.00"      INR
# 2           1398.0    "₹475.00"      INR
# 3           3329.0    "₹732.00"      INR
# 4            799.0    "₹431.00"      INR
# ..             ...          ...      ...
# 117         2495.0  "₹2,495.00"      INR
# 118         3329.0    "₹732.00"      INR
# 119         1599.0    "₹479.00"      INR
# 120          449.0    "₹449.00"      INR
# 121         1578.0    "₹631.00"      INR
#
#                                                 images  \
# 0    http://assets.myntassets.com/assets/images/186...
# 1    http://assets.myntassets.com/assets/images/189...
# 2    http://assets.myntassets.com/assets/images/189...
# 3    http://assets.myntassets.com/assets/images/189...
# 4    http://assets.myntassets.com/assets/images/189...
# ..                                                 ...
# 117  http://assets.myntassets.com/assets/images/189...
# 118  http://assets.myntassets.com/assets/images/189...
# 119  http://assets.myntassets.com/assets/images/137...
# 120  http://assets.myntassets.com/assets/images/225...
# 121  http://assets.myntassets.com/assets/images/192...
#
#                                       delivery_options  \
# 0    ["100% Original Products","Pay on delivery mig...
# 1    ["100% Original Products","Pay on delivery mig...
# 2    ["100% Original Products","Pay on delivery mig...
# 3    ["100% Original Products","Pay on delivery mig...
# 4    ["100% Original Products","Pay on delivery mig...
# ..                                                 ...
# 117  ["100% Original Products","Pay on delivery mig...
# 118  ["100% Original Products","Pay on delivery mig...
# 119  ["100% Original Products","Pay on delivery mig...
# 120  ["100% Original Products","Pay on delivery mig...
# 121  ["100% Original Products","Pay on delivery mig...
#
#                                        product_details  \
# 0    {"description":"  Blue crop blouson top   Soli...
# 1    {"description":"  Yellow and red regular peplu...
# 2    {"description":"Blue and pink regular A-line t...
# 3    {"description":"  Green regular wrap top   Eth...
# 4    {"description":"  White and navy blue regular ...
# ..                                                 ...
# 117  {"description":"Special Technology:Engineered ...
# 118  {"description":"Yellow regular wrap topEthnic ...
# 119  {"description":"Colour: peach-coloured regular...
# 120  {"description":"Yellow blouson topSolidRound n...
# 121  {"description":"  Black regular tank top   Sol...
#
#                                            breadcrumbs  \
# 0    [{"name":"Clothing","url":"https://www.myntra....
# 1    [{"name":"Clothing","url":"https://www.myntra....
# 2    [{"name":"Clothing","url":"https://www.myntra....
# 3    [{"name":"Clothing","url":"https://www.myntra....
# 4    [{"name":"Clothing","url":"https://www.myntra....
# ..                                                 ...
# 117  [{"name":"Clothing","url":"https://www.myntra....
# 118  [{"name":"Clothing","url":"https://www.myntra....
# 119  [{"name":"Clothing","url":"https://www.myntra....
# 120  [{"name":"Clothing","url":"https://www.myntra....
# 121  [{"name":"Clothing","url":"https://www.myntra....
#
#                                 product_specifications  \
# 0    [{"specification_name":"Body Shape ID","specif...
# 1    [{"specification_name":"Body Shape ID","specif...
# 2    [{"specification_name":"Body Shape ID","specif...
# 3    [{"specification_name":"Body Shape ID","specif...
# 4    [{"specification_name":"Body or Garment Size",...
# ..                                                 ...
# 117  [{"specification_name":"Body Shape ID","specif...
# 118  [{"specification_name":"Body Shape ID","specif...
# 119  [{"specification_name":"Body Shape ID","specif...
# 120  [{"specification_name":"Body Shape ID","specif...
# 121  [{"specification_name":"Body Shape ID","specif...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 18 columns]

# %%
df
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       NaN  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       NaN    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                NaN
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                  NaN
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                  NaN
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                  NaN
# 120  Plo███o.8███ Se█████████Pha███████████████████...                  NaN
# 121  Fla███o 6███jay█████████s, ███████████████████...                  NaN
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       0.0  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                    0
# 1                                                    0
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                  0
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                    0
# 1                                                    0
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                    0
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                    0
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                    0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                    0
# 121  Fla███o 6███jay█████████s, ███████████████████...                    0
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %% [markdown]
# # Task 4
# * Perform basic operations (filter rows, select columns)

# %%
df_filled[df_filled['rating']>0]
# Out:
#      product_id            title  \
# 2      18937628  her by invictus
# 6      18990292      HILL STREET
# 7      18972748      Zink London
# 9      18904492            Levis
# 11     13583566        Chemistry
# ..          ...              ...
# 115    18000968            Harpa
# 116    18937522  her by invictus
# 117    18962100             Nike
# 119    13748756           Madame
# 120    22568668           V-Mart
#
#                                    product_description  rating  ratings_count  \
# 2                                   Printed A-Line Top     4.2             29
# 6    Women Fluorescent Green Solid Pure Cotton Tank...     4.5             15
# 7                           Yellow Geometric Print Top     4.3              7
# 9    Women Sage Green Self Design Slim Fit Regular Top     4.4             50
# 11       Navy Blue Regular Top with Embroidered Detail     4.5             20
# ..                                                 ...     ...            ...
# 115                     Women Maroon V-Neck Casual Top     4.4             21
# 116                        V-Neck Textured Regular Top     3.9             57
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
#
#      initial_price  discount  final_price currency  \
# 2           1398.0      66.0    "₹475.00"      INR
# 6           1699.0      65.0    "₹594.00"      INR
# 7           1499.0      65.0    "₹524.00"      INR
# 9           2099.0      20.0  "₹1,133.00"      INR
# 11          1499.0       0.0  "₹1,499.00"      INR
# ..             ...       ...          ...      ...
# 115         1049.0      48.0  "₹1,049.00"      INR
# 116         1298.0      65.0    "₹454.00"      INR
# 117         2495.0       0.0  "₹2,495.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
#
#                                                 images  ...  \
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 6    http://assets.myntassets.com/assets/images/189...  ...
# 7    http://assets.myntassets.com/assets/images/189...  ...
# 9    http://assets.myntassets.com/assets/images/189...  ...
# 11   http://assets.myntassets.com/assets/images/135...  ...
# ..                                                 ...  ...
# 115  http://assets.myntassets.com/assets/images/180...  ...
# 116  http://assets.myntassets.com/assets/images/189...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
#
#                                        amount_of_stars  \
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 6    {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 7    {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 9    {"1_star":4,"2_stars":1,"3_stars":2,"4_stars":...
# 11   {"1_star":0,"2_stars":1,"3_stars":2,"4_stars":...
# ..                                                 ...
# 115  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 116  {"1_star":7,"2_stars":4,"3_stars":6,"4_stars":...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
#
#                                    what_customers_said  \
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 6    [{"percentage":"100","value_name":"Fit, Just R...
# 7                                                    0
# 9    [{"percentage":"67","value_name":"Fit, Just Ri...
# 11                                                   0
# ..                                                 ...
# 115                                                  0
# 116  [{"percentage":"67","value_name":"Fit, A Littl...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
#
#                         seller_name  \
# 2                      Sup███om ███
# 6          HIL███TRE███LIF█████████
# 7    FRE███ GL███L P█████████MIT███
# 9        Lev███tra███ In█████████td
# 11                                0
# ..                              ...
# 115                               0
# 116                    Sup███om ███
# 117      Nik███ndi███riv█████████ed
# 119      JAI███MAR███OTH█████████TD
# 120        V-M███ Re███l L█████████
#
#                                                  sizes  \
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 6    [{"size":"S","value":"34.0in","value_name":"To...
# 7    [{"size":"XS","value":"32.0in","value_name":"T...
# 9    [{"size":"XS","value":"37.5in","value_name":"B...
# 11   [{"size":"XS","value":"32.0in","value_name":"T...
# ..                                                 ...
# 115  [{"size":"XS","value":"30.0in","value_name":"T...
# 116  [{"size":"S","value":"34.0in","value_name":"To...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
#
#                                                 videos  \
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 6                                                    0
# 7                                                    0
# 9    ["https://videos.myntassets.com/assets/videos/...
# 11   ["rw-13583566_cae700","https://videos.myntasse...
# ..                                                 ...
# 115                                                  0
# 116                             ["rw-18937522_cae700"]
# 117                             ["rw-18962100_cae700"]
# 119                                                  0
# 120                                                  0
#
#                                     seller_information        variations  \
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                 0
# 6    50,███OCK███ AS█████████PHA███████████████████...                 0
# 7    148███49,███0 A█████████lla███████████████████...                 0
# 9    Eco███xpr███ Pv█████████no ███████████████████...                 0
# 11                                                   0           [{},{}]
# ..                                                 ...               ...
# 115                                                  0  [{},{},{},{},{}]
# 116  Plo███o- ███ 1s█████████Sui███████████████████...              [{}]
# 117  Oly███a B███din█████████e T███████████████████...                 0
# 119  CIN███520███200█████████0 #███████████████████...                 0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                 0
#
#                                             best_offer  \
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 6    {"applicable_on":"Orders above Rs. 649 (only o...
# 7    {"applicable_on":"Orders above Rs. 649 (only o...
# 9    {"applicable_on":"Orders above Rs. 1099 (only ...
# 11                                                  {}
# ..                                                 ...
# 115                                                 {}
# 116  {"applicable_on":"Orders above Rs. 649 (only o...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 6    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 7    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 9    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 11   [{"offer_name":"10% Instant Discount on Citi C...     tops
# ..                                                 ...      ...
# 115  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 116  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [106 rows x 24 columns]

# %%
df
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       NaN  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       NaN    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                NaN
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                  NaN
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                  NaN
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                  NaN
# 120  Plo███o.8███ Se█████████Pha███████████████████...                  NaN
# 121  Fla███o 6███jay█████████s, ███████████████████...                  NaN
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %%
df['final_price'] = pd.to_numeric(
    df['final_price']
    .str.replace('₹', '', regex=False)
    .str.replace('"', '', regex=False),
    errors='coerce'
)

# %%
df[(df['final_price'] > 500) & (df['final_price'] < 1000)]
# Out:
#      product_id                    title  \
# 0      18614510                 Oxolloxo
# 1      18972586                  MALHAAR
# 3      18972622                  MALHAAR
# 5      18972618                  MALHAAR
# 6      18990292              HILL STREET
# 7      18972748              Zink London
# 8      18998738                   KALINI
# 10     18972644                  MALHAAR
# 12     18551958                 SHECZZAR
# 17     13573344                 Roadster
# 19     20222156        CODE by Lifestyle
# 20     20405594                   AAHWAN
# 26     15888984                 Friskers
# 29     18478530                Paralians
# 36     17178948               FOREVER 21
# 37     17132266                   Athena
# 41     18803468                 Oxolloxo
# 42     17253026                   Athena
# 43     22649882                     IUGA
# 47     19018090               DressBerry
# 50     19018146               DressBerry
# 51     17268524                      H&M
# 54     18972596                  MALHAAR
# 55     17124636                      H&M
# 60     18980478              DEBONATELLA
# 62     18900376               DressBerry
# 66     19017944               DressBerry
# 67     17114132                 HERE&NOW
# 71     18975854      Honey by Pantaloons
# 72     18849012                 Fleximaa
# 75      7206166                    Mayra
# 77     18944780           Miaz Lifestyle
# 79     17889776             CHIMPAAANZEE
# 82     17938374        CODE by Lifestyle
# 89      7581747  Annabelle by Pantaloons
# 90      9818669                   Globus
# 94      9327149              Belle Fille
# 96     18780000                 Popwings
# 99      8807033           Flying Machine
# 101    19024914           Miaz Lifestyle
# 104    11811068      Honey by Pantaloons
# 106    17982570                      H&M
# 111    11538822      Ajile by Pantaloons
# 114      586846                   Cation
# 118    18972666                  MALHAAR
# 121    19297208                 Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 3                                 Green Print Wrap Top     0.0              0
# 5                 Red Print Mandarin Collar Peplum Top     0.0              0
# 6    Women Fluorescent Green Solid Pure Cotton Tank...     4.5             15
# 7                           Yellow Geometric Print Top     4.3              7
# 8     Green & charleston green Animal Print Indigo Top     0.0              0
# 10   Blue & Pink Floral Print Mandarin Collar Peplu...     0.0              0
# 12           Women White & Black Striped Georgette Top     3.8              6
# 17   The  Lifestyle Co Black Solid Pure Cotton Regu...     4.0            280
# 19                                    Solid V-Neck Top     4.1             47
# 20                             White Bralette Crop Top     3.2            166
# 26                                      Black Tank Top     0.0              0
# 29                             White Print  peplum Top     3.7            454
# 36    Women Grey Solid Cloud Wash Crop Cotton Tank Top     4.4             11
# 37   Women Attractive Lime Green Solid Halter Neck Top     3.7             10
# 41                                 White Geometric Top     0.0              0
# 42                      Green Floral Print Blouson Top     3.9            113
# 43                 Notched Neck Short Sleeves Crop Top     3.0              6
# 47                      Burgundy Pure Cotton Solid Top     4.1            102
# 50             Women Green Solid Scoop Neck Fitted Top     4.0            110
# 51                 Women Brown Halter Neck Cropped Top     4.4            203
# 54       White & Brown Print Smocked Cinched Waist Top     0.0              0
# 55                  Women Grey Pure Cotton Cropped Top     3.7             25
# 60                       White Print Ruffles Crepe Top     3.0              2
# 62                  Coffee Brown Pure Cotton Solid Top     3.7            332
# 66                                       Rust Tank Top     4.1             94
# 67                         Women Black Fitted Crop Top     4.1             51
# 71      Blue & orchid tint Floral Print Linen Crop Top     0.0              0
# 72   Red & Blue Pack of 2 Pure Cotton Typography Lo...     0.0              0
# 75                            Women Yellow Printed Top     2.4             34
# 77                 Pack of 2 Peach-Coloured & Red Tops     2.7              3
# 79           White Striped Extended Sleeves Peplum Top     3.9             13
# 82             White & Turquoise Blue Floral Print Top     4.4             17
# 89                              Women Blue Printed Top     4.3             50
# 90                                Women Pink Solid Top     4.3              8
# 94                   Women Grey Melange Solid Crop Top     3.8              4
# 96   Yellow & sahara sun Floral Print Chiffon Empir...     3.7             31
# 99                  Women Blue Printed Pure Cotton Top     3.7             14
# 101    Women Pack Of 2 Black & Peach-Coloured Crop Top     0.0              0
# 104               Women Pink Floral Printed A-Line Top     4.4             15
# 106              Women Brown Lacing-Detail Cut-Out Top     4.5             52
# 111                     Women Grey Melange Printed Top     4.2             17
# 114                                    Women Black Top     4.5             11
# 118                              Yellow Print Wrap Top     0.0              0
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0        599.0      INR
# 1           3329.0      79.0        699.0      INR
# 3           3329.0      78.0        732.0      INR
# 5           3329.0      79.0        699.0      INR
# 6           1699.0      65.0        594.0      INR
# 7           1499.0      65.0        524.0      INR
# 8           1999.0      74.0        519.0      INR
# 10          3329.0      79.0        699.0      INR
# 12           799.0      53.0        799.0      INR
# 17           699.0       NaN        699.0      INR
# 19           799.0      30.0        799.0      INR
# 20           999.0      50.0        999.0      INR
# 26           978.0      42.0        567.0      INR
# 29           999.0      50.0        999.0      INR
# 36          1049.0      50.0        524.0      INR
# 37          1499.0      64.0        539.0      INR
# 41          1499.0      56.0        659.0      INR
# 42          1699.0      70.0        509.0      INR
# 43          1299.0      57.0        558.0      INR
# 47           799.0       NaN        799.0      INR
# 50           899.0      56.0        899.0      INR
# 51           699.0      25.0        699.0      INR
# 54          3329.0      82.0        599.0      INR
# 55           799.0      25.0        799.0      INR
# 60           600.0      26.0        600.0      INR
# 62           699.0       NaN        699.0      INR
# 66           799.0       NaN        799.0      INR
# 67           999.0       NaN        999.0      INR
# 71          1099.0      40.0        659.0      INR
# 72          1799.0      50.0        899.0      INR
# 75           895.0      70.0        895.0      INR
# 77          1499.0      58.0        629.0      INR
# 79           699.0      47.0        699.0      INR
# 82           999.0      30.0        999.0      INR
# 89           899.0      25.0        899.0      INR
# 90           999.0      60.0        999.0      INR
# 94           999.0      50.0        999.0      INR
# 96          1999.0      69.0        619.0      INR
# 99           799.0      60.0        799.0      INR
# 101         1499.0      56.0        659.0      INR
# 104          999.0      35.0        999.0      INR
# 106          999.0      25.0        999.0      INR
# 111          599.0       8.0        599.0      INR
# 114          899.0      40.0        899.0      INR
# 118         3329.0      78.0        732.0      INR
# 121         1578.0      60.0        631.0      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 5    http://assets.myntassets.com/assets/images/189...  ...
# 6    http://assets.myntassets.com/assets/images/189...  ...
# 7    http://assets.myntassets.com/assets/images/189...  ...
# 8    http://assets.myntassets.com/assets/images/189...  ...
# 10   http://assets.myntassets.com/assets/images/189...  ...
# 12   http://assets.myntassets.com/assets/images/185...  ...
# 17   http://assets.myntassets.com/assets/images/135...  ...
# 19   http://assets.myntassets.com/assets/images/202...  ...
# 20   http://assets.myntassets.com/assets/images/204...  ...
# 26   http://assets.myntassets.com/assets/images/158...  ...
# 29   http://assets.myntassets.com/assets/images/184...  ...
# 36   http://assets.myntassets.com/assets/images/171...  ...
# 37   http://assets.myntassets.com/assets/images/171...  ...
# 41   http://assets.myntassets.com/assets/images/188...  ...
# 42   http://assets.myntassets.com/assets/images/172...  ...
# 43   http://assets.myntassets.com/assets/images/226...  ...
# 47   http://assets.myntassets.com/assets/images/190...  ...
# 50   http://assets.myntassets.com/assets/images/190...  ...
# 51   http://assets.myntassets.com/assets/images/172...  ...
# 54   http://assets.myntassets.com/assets/images/189...  ...
# 55   http://assets.myntassets.com/assets/images/171...  ...
# 60   http://assets.myntassets.com/assets/images/189...  ...
# 62   http://assets.myntassets.com/assets/images/189...  ...
# 66   http://assets.myntassets.com/assets/images/190...  ...
# 67   http://assets.myntassets.com/assets/images/171...  ...
# 71   http://assets.myntassets.com/assets/images/189...  ...
# 72   http://assets.myntassets.com/assets/images/188...  ...
# 75   http://assets.myntassets.com/assets/images/720...  ...
# 77   http://assets.myntassets.com/assets/images/189...  ...
# 79   http://assets.myntassets.com/assets/images/178...  ...
# 82   http://assets.myntassets.com/assets/images/179...  ...
# 89   http://assets.myntassets.com/assets/images/758...  ...
# 90   http://assets.myntassets.com/assets/images/981...  ...
# 94   http://assets.myntassets.com/assets/images/932...  ...
# 96   http://assets.myntassets.com/assets/images/187...  ...
# 99   http://assets.myntassets.com/assets/images/pro...  ...
# 101  http://assets.myntassets.com/assets/images/190...  ...
# 104  http://assets.myntassets.com/assets/images/118...  ...
# 106  http://assets.myntassets.com/assets/images/179...  ...
# 111  http://assets.myntassets.com/assets/images/pro...  ...
# 114  http://assets.myntassets.com/v1/images/style/p...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 5    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 6    {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 7    {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 8    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 10   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 12   {"1_star":0,"2_stars":2,"3_stars":0,"4_stars":...
# 17   {"1_star":20,"2_stars":17,"3_stars":44,"4_star...
# 19   {"1_star":6,"2_stars":0,"3_stars":5,"4_stars":...
# 20   {"1_star":47,"2_stars":13,"3_stars":24,"4_star...
# 26   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 29   {"1_star":58,"2_stars":35,"3_stars":68,"4_star...
# 36   {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 37   {"1_star":2,"2_stars":1,"3_stars":1,"4_stars":...
# 41   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 42   {"1_star":12,"2_stars":8,"3_stars":14,"4_stars...
# 43   {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...
# 47   {"1_star":8,"2_stars":4,"3_stars":11,"4_stars"...
# 50   {"1_star":12,"2_stars":11,"3_stars":7,"4_stars...
# 51   {"1_star":6,"2_stars":8,"3_stars":12,"4_stars"...
# 54   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 55   {"1_star":5,"2_stars":2,"3_stars":0,"4_stars":...
# 60   {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 62   {"1_star":43,"2_stars":27,"3_stars":64,"4_star...
# 66   {"1_star":6,"2_stars":3,"3_stars":12,"4_stars"...
# 67   {"1_star":3,"2_stars":4,"3_stars":9,"4_stars":...
# 71   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 72   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 75   {"1_star":18,"2_stars":1,"3_stars":5,"4_stars"...
# 77   {"1_star":1,"2_stars":1,"3_stars":0,"4_stars":...
# 79   {"1_star":1,"2_stars":0,"3_stars":3,"4_stars":...
# 82   {"1_star":1,"2_stars":0,"3_stars":2,"4_stars":...
# 89   {"1_star":3,"2_stars":2,"3_stars":3,"4_stars":...
# 90   {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 94   {"1_star":0,"2_stars":0,"3_stars":2,"4_stars":...
# 96   {"1_star":5,"2_stars":1,"3_stars":6,"4_stars":...
# 99   {"1_star":3,"2_stars":0,"3_stars":1,"4_stars":...
# 101  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 104  {"1_star":1,"2_stars":0,"3_stars":2,"4_stars":...
# 106  {"1_star":3,"2_stars":1,"3_stars":3,"4_stars":...
# 111  {"1_star":0,"2_stars":1,"3_stars":3,"4_stars":...
# 114  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                  NaN
# 1                                                  NaN
# 3                                                  NaN
# 5    [{"percentage":"100","value_name":"Fit, Just R...
# 6    [{"percentage":"100","value_name":"Fit, Just R...
# 7                                                  NaN
# 8                                                  NaN
# 10                                                 NaN
# 12   [{"percentage":"100","value_name":"Fit, Just R...
# 17   [{"percentage":"79","value_name":"Fit, Just Ri...
# 19   [{"percentage":"100","value_name":"Fit, Just R...
# 20   [{"percentage":"86","value_name":"Fit, Just Ri...
# 26                                                 NaN
# 29   [{"percentage":"59","value_name":"Fit, Just Ri...
# 36                                                 NaN
# 37                                                 NaN
# 41                                                 NaN
# 42   [{"percentage":"100","value_name":"Fit, Just R...
# 43                                                 NaN
# 47   [{"percentage":"71","value_name":"Fit, Just Ri...
# 50   [{"percentage":"67","value_name":"Fit, Just Ri...
# 51                                                 NaN
# 54                                                 NaN
# 55   [{"percentage":"100","value_name":"Fit, Just R...
# 60   [{"percentage":"100","value_name":"Fit, Just R...
# 62   [{"percentage":"62","value_name":"Fit, Just Ri...
# 66                                                 NaN
# 67   [{"percentage":"100","value_name":"Fit, Just R...
# 71   [{"percentage":"100","value_name":"Fit, A Litt...
# 72                                                 NaN
# 75   [{"percentage":"34","value_name":"Fit, Tight"}...
# 77                                                 NaN
# 79   [{"percentage":"50","value_name":"Fit, Just Ri...
# 82   [{"percentage":"100","value_name":"Fit, Just R...
# 89   [{"percentage":"100","value_name":"Fit, Just R...
# 90   [{"percentage":"67","value_name":"Fit, Just Ri...
# 94   [{"percentage":"100","value_name":"Fit, Just R...
# 96                                                 NaN
# 99   [{"percentage":"100","value_name":"Fit, Just R...
# 101                                                NaN
# 104                                                NaN
# 106  [{"percentage":"100","value_name":"Fit, Just R...
# 111  [{"percentage":"80","value_name":"Fit, Just Ri...
# 114  [{"percentage":"67","value_name":"Fit, Just Ri...
# 118                                                NaN
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 3                         BED███E S███IES██████
# 5                         BED███E S███IES██████
# 6                      HIL███TRE███LIF█████████
# 7                FRE███ GL███L P█████████MIT███
# 8                            Oma███Ent███ris███
# 10                        BED███E S███IES██████
# 12                                          NaN
# 17                                          NaN
# 19                                          NaN
# 20                                          NaN
# 26                                       Fly███
# 29                                          NaN
# 36            Wes███ry ███din█████████d_M██████
# 37         MAY███I L███STY█████████E L█████████
# 41               KPA███PAR███ PR█████████ITE███
# 42                                APE███PPA███S
# 43                        ARB███R C███ECT██████
# 47                                          NaN
# 50                                          NaN
# 51                                          NaN
# 54                        BED███E S███IES██████
# 55                                          NaN
# 60                                          NaN
# 62                                          NaN
# 66                                          NaN
# 67                                          NaN
# 71      Wes███ry ███din█████████d_P████████████
# 72                           FLE███LE ███ARE███
# 75                                          NaN
# 77                               Mia███ife███le
# 79                                          NaN
# 82                                          NaN
# 89                                          NaN
# 90                                          NaN
# 94                                          NaN
# 96         POP███GS ███OMM█████████ATE█████████
# 99                                          NaN
# 101                              Mia███ife███le
# 104                                         NaN
# 106                                         NaN
# 111                                         NaN
# 114                                         NaN
# 118                       BED███E S███IES██████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 5    [{"size":"XS","value":"33.0in","value_name":"T...
# 6    [{"size":"S","value":"34.0in","value_name":"To...
# 7    [{"size":"XS","value":"32.0in","value_name":"T...
# 8    [{"size":"XS","value":"34.0in","value_name":"B...
# 10   [{"size":"S","value":"35.0in","value_name":"To...
# 12   [{"size":"S","value":"34.0in","value_name":"Bu...
# 17   [{"size":"XS","value":"33.5in","value_name":"B...
# 19   [{"size":"XS","value":"30.0in","value_name":"B...
# 20   [{"size":"Onesize","value":"26.0in","value_nam...
# 26   [{"size":"S","value":"30.0in","value_name":"Bu...
# 29   [{"size":"XS","value":"34.0in","value_name":"T...
# 36   [{"size":"XS","value":"32.0in","value_name":"T...
# 37   [{"size":"XS","value":"32.0in","value_name":"T...
# 41   [{"size":"S","value":"34.0in","value_name":"To...
# 42   [{"size":"XS","value":"32.0in","value_name":"T...
# 43   [{"size":"S","value":"34.0in","value_name":"To...
# 47   [{"size":"XS","value":"32.0in","value_name":"T...
# 50   [{"size":"XS","value":"32.0in","value_name":"T...
# 51   [{"size":"XXS","value":"30.0in","value_name":"...
# 54   [{"size":"XS","value":"33.0in","value_name":"T...
# 55   [{"size":"XXS","value":"30.0in","value_name":"...
# 60   [{"size":"S","value":"37.0in","value_name":"Bu...
# 62   [{"size":"XS","value":"32.0in","value_name":"T...
# 66   [{"size":"XS","value":"32.0in","value_name":"T...
# 67   [{"size":"XS","value":"32.0in","value_name":"T...
# 71   [{"size":"XS","value":"35.0in","value_name":"B...
# 72   [{"size":"S","value":"34.0in","value_name":"Bu...
# 75   [{"size":"S","value":"34.0in","value_name":"To...
# 77   [{"size":"XS","value":"28.0in","value_name":"B...
# 79   [{"size":"S","value":"38.0in","value_name":"Bu...
# 82   [{"size":"XS","value":"30.0in","value_name":"B...
# 89   [{"size":"XS","value":"36.0in","value_name":"B...
# 90   [{"size":"XS","value":"32.0in","value_name":"B...
# 94   [{"size":"S","value":"34.0in","value_name":"To...
# 96   [{"size":"S","value":"32.0in","value_name":"To...
# 99   [{"size":"XS","value":"32.0in","value_name":"T...
# 101  [{"size":"XS","value":"28.0in","value_name":"B...
# 104  [{"size":"XS","value":"34.0in","value_name":"B...
# 106  [{"size":"XXS","value":"30.0in","value_name":"...
# 111  [{"size":"S","value":"36.0in","value_name":"Bu...
# 114  [{"size":"S","value":"34.0in","value_name":"Bu...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                  NaN
# 1                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 10                                                 NaN
# 12                                                 NaN
# 17                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 26                                                 NaN
# 29                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 47                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 60                                                 NaN
# 62                                                 NaN
# 66   ["https://videos.myntassets.com/assets/videos/...
# 67   ["rw-17114132_cae700","https://videos.myntasse...
# 71                                                 NaN
# 72                                                 NaN
# 75                                                 NaN
# 77                                                 NaN
# 79                                                 NaN
# 82                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 94                                                 NaN
# 96                                                 NaN
# 99                                                 NaN
# 101                                                NaN
# 104                                                NaN
# 106                                                NaN
# 111                                                NaN
# 114                                                NaN
# 118                                                NaN
# 121                                                NaN
#
#                                     seller_information  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...
# 1    1/4███Rii███Ind█████████rea███████████████████...
# 3    1/4███Rii███Ind█████████rea███████████████████...
# 5    1/4███Rii███Ind█████████rea███████████████████...
# 6    50,███OCK███ AS█████████PHA███████████████████...
# 7    148███49,███0 A█████████lla███████████████████...
# 8    PAR███NAT███ARA█████████ PL███████████████████...
# 10   1/4███Rii███Ind█████████rea███████████████████...
# 12                                                 NaN
# 17                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 26   Fla███o 6███jay█████████s, ███████████████████...
# 29                                                 NaN
# 36   Gro███ Fl███, N█████████old███████████████████...
# 37    P.N███61/███ Se█████████rga█████████████████████
# 41    C-1███ect███- 6█████████Utt█████████████████████
# 42   Plo███o. ███, P█████████2Se███████████████████...
# 43   KH ███443███ND █████████C L███████████████████...
# 47                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 54   1/4███Rii███Ind█████████rea███████████████████...
# 55                                                 NaN
# 60                                                 NaN
# 62                                                 NaN
# 66                                                 NaN
# 67                                                 NaN
# 71   Wes███ry ███din█████████e L███████████████████...
# 72   82,███VER███TRE█████████DUT███████████████████...
# 75                                                 NaN
# 77       B-4███ubh███ Kh█████████lhi██████████████████
# 79                                                 NaN
# 82                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 94                                                 NaN
# 96   Wz-███, A███, F█████████r,H███████████████████...
# 99                                                 NaN
# 101      B-4███ubh███ Kh█████████lhi██████████████████
# 104                                                NaN
# 106                                                NaN
# 111                                                NaN
# 114                                                NaN
# 118  1/4███Rii███Ind█████████rea███████████████████...
# 121  Fla███o 6███jay█████████s, ███████████████████...
#
#                                    variations  \
# 0                                        [{}]
# 1                         [{},{},{},{},{},{}]
# 3                                  [{},{},{}]
# 5                         [{},{},{},{},{},{}]
# 6                                         NaN
# 7                                         NaN
# 8                               [{},{},{},{}]
# 10                        [{},{},{},{},{},{}]
# 12                                        NaN
# 17                                       [{}]
# 19                                        NaN
# 20                                 [{},{},{}]
# 26      [{},{},{},{},{},{},{},{},{},{},{},{}]
# 29                                        NaN
# 36                                        NaN
# 37                                 [{},{},{}]
# 41                              [{},{},{},{}]
# 42                                    [{},{}]
# 43                                        NaN
# 47                                 [{},{},{}]
# 50                                        NaN
# 51                           [{},{},{},{},{}]
# 54                           [{},{},{},{},{}]
# 55         [{},{},{},{},{},{},{},{},{},{},{}]
# 60                                        NaN
# 62                                    [{},{}]
# 66                                 [{},{},{}]
# 67                                        NaN
# 71                                        NaN
# 72   [{},{},{},{},{},{},{},{},{},{},{},{},{}]
# 75                                        NaN
# 77            [{},{},{},{},{},{},{},{},{},{}]
# 79                                        NaN
# 82                                        NaN
# 89                                        NaN
# 90                                        NaN
# 94                                        NaN
# 96                        [{},{},{},{},{},{}]
# 99                                        NaN
# 101                                [{},{},{}]
# 104                                   [{},{}]
# 106                             [{},{},{},{}]
# 111                                       NaN
# 114                                       NaN
# 118                                [{},{},{}]
# 121                                       NaN
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 5    {"applicable_on":"Orders above Rs. 999 (only o...
# 6    {"applicable_on":"Orders above Rs. 649 (only o...
# 7    {"applicable_on":"Orders above Rs. 649 (only o...
# 8    {"applicable_on":"Orders above Rs. 649 (only o...
# 10   {"applicable_on":"Orders above Rs. 999 (only o...
# 12                                                  {}
# 17                                                  {}
# 19                                                  {}
# 20                                                  {}
# 26   {"applicable_on":"Orders above Rs. 649 (only o...
# 29                                                  {}
# 36   {"applicable_on":"Orders above Rs. 649 (only o...
# 37   {"applicable_on":"Orders above Rs. 649 (only o...
# 41   {"applicable_on":"Orders above Rs. 649 (only o...
# 42   {"applicable_on":"Orders above Rs. 649 (only o...
# 43   {"applicable_on":"Orders above Rs. 649 (only o...
# 47                                                  {}
# 50                                                  {}
# 51                                                  {}
# 54   {"applicable_on":"Orders above Rs. 649 (only o...
# 55                                                  {}
# 60                                                  {}
# 62                                                  {}
# 66                                                  {}
# 67                                                  {}
# 71   {"applicable_on":"Orders above Rs. 649 (only o...
# 72   {"applicable_on":"Orders above Rs. 999 (only o...
# 75                                                  {}
# 77   {"applicable_on":"Orders above Rs. 649 (only o...
# 79                                                  {}
# 82                                                  {}
# 89                                                  {}
# 90                                                  {}
# 94                                                  {}
# 96   {"applicable_on":"Orders above Rs. 649 (only o...
# 99                                                  {}
# 101  {"applicable_on":"Orders above Rs. 649 (only o...
# 104                                                 {}
# 106                                                 {}
# 111                                                 {}
# 114                                                 {}
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 5    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 6    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 7    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 8    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 10   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 12   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 17   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 19   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 20   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 26   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 29   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 36   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 37   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 41   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 42   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 43   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 47   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 50   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 51   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 54   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 55   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 60   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 62   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 66   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 67   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 71   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 72   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 75   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 77   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 79   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 82   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 89   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 90   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 94   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 96   [{"offer_name":"10% Instant Discount on IndusI...     tops
# 99   [{"offer_name":"10% Instant Discount on Citi C...     tops
# 101  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 104  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 106  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 111  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 114  [{"offer_name":"10% Instant Discount on Citi C...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [46 rows x 24 columns]

# %%
df[["title","product_description","rating","final_price","delivery_options","discount"]]
# Out:
#                title                                product_description  \
# 0           Oxolloxo                  Women Blue Crepe Blouson Crop Top
# 1            MALHAAR  Yellow & Red Geometric Print Mandarin Collar C...
# 2    her by invictus                                 Printed A-Line Top
# 3            MALHAAR                               Green Print Wrap Top
# 4         KiddoPanti  White & Navy Blue Geometric Print Georgette Sh...
# ..               ...                                                ...
# 117             Nike         Women Black Brand Logo Printed Dri Fit Top
# 118          MALHAAR                              Yellow Print Wrap Top
# 119           Madame              Women Peach-Coloured Self Checked Top
# 120           V-Mart      High Neck Puff Sleeves Gathered Georgette Top
# 121         Friskers          Women Black Solid Organic Cotton Tank Top
#
#      rating  final_price                                   delivery_options  \
# 0       0.0        599.0  ["100% Original Products","Pay on delivery mig...
# 1       0.0        699.0  ["100% Original Products","Pay on delivery mig...
# 2       4.2        475.0  ["100% Original Products","Pay on delivery mig...
# 3       0.0        732.0  ["100% Original Products","Pay on delivery mig...
# 4       0.0        431.0  ["100% Original Products","Pay on delivery mig...
# ..      ...          ...                                                ...
# 117     4.4          NaN  ["100% Original Products","Pay on delivery mig...
# 118     0.0        732.0  ["100% Original Products","Pay on delivery mig...
# 119     3.6        479.0  ["100% Original Products","Pay on delivery mig...
# 120     3.7        449.0  ["100% Original Products","Pay on delivery mig...
# 121     0.0        631.0  ["100% Original Products","Pay on delivery mig...
#
#      discount
# 0        73.0
# 1        79.0
# 2        66.0
# 3        78.0
# 4        46.0
# ..        ...
# 117       NaN
# 118      78.0
# 119      70.0
# 120       NaN
# 121      60.0
#
# [122 rows x 6 columns]

# %% [markdown]
# # Task 5
# * Remove Duplicates

# %%
df_filled.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_filled.drop_duplicates(ignore_index=True)
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       0.0  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                    0
# 1                                                    0
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                  0
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                    0
# 1                                                    0
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                    0
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                    0
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                    0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                    0
# 121  Fla███o 6███jay█████████s, ███████████████████...                    0
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %% [markdown]
# * As in the csv file there are no duplicates, so to remove duplicates from any file we can use this method with example

# %%
df1 = pd.DataFrame({'Name':["Ajay","Kinshu","Ajay","Jatin"],'Marks':[85,92,85,93]})
df1
# Out:
#      Name  Marks
# 0    Ajay     85
# 1  Kinshu     92
# 2    Ajay     85
# 3   Jatin     93

# %%
df1.duplicated().sum()
# Out:
# np.int64(1)

# %%
df1_cleaned = df1.drop_duplicates(ignore_index=True)

# %%
df1_cleaned
# Out:
#      Name  Marks
# 0    Ajay     85
# 1  Kinshu     92
# 2   Jatin     93

# %% [markdown]
# # Task 6
# * Create a derived column (total_amount = price * quantity).

# %%
df_filled
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       0.0  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 1    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 2    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 3    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 117  {"1_star":5,"2_stars":0,"3_stars":3,"4_stars":...
# 118  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 119  {"1_star":7,"2_stars":3,"3_stars":4,"4_stars":...
# 120  {"1_star":6,"2_stars":0,"3_stars":2,"4_stars":...
# 121  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 0                                                    0
# 1                                                    0
# 2    [{"percentage":"100","value_name":"Fit, Just R...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117  [{"percentage":"100","value_name":"Fit, Just R...
# 118                                                  0
# 119  [{"percentage":"100","value_name":"Fit, Just R...
# 120  [{"percentage":"100","value_name":"Fit, Just R...
# 121  [{"percentage":"100","value_name":"Fit, A Litt...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                    0
# 1                                                    0
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                    0
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                    0
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                    0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                    0
# 121  Fla███o 6███jay█████████s, ███████████████████...                    0
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops
# ..                                                 ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops
#
# [122 rows x 24 columns]

# %%
df_filled.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              122 non-null    int64
#  1   title                   122 non-null    str
#  2   product_description     122 non-null    str
#  3   rating                  122 non-null    float64
#  4   ratings_count           122 non-null    int64
#  5   initial_price           122 non-null    float64
#  6   discount                122 non-null    float64
#  7   final_price             122 non-null    str
#  8   currency                122 non-null    str
#  9   images                  122 non-null    str
#  10  delivery_options        122 non-null    str
#  11  product_details         122 non-null    str
#  12  breadcrumbs             122 non-null    str
#  13  product_specifications  122 non-null    str
#  14  amount_of_stars         122 non-null    str
#  15  what_customers_said     122 non-null    object
#  16  seller_name             122 non-null    object
#  17  sizes                   122 non-null    str
#  18  videos                  122 non-null    object
#  19  seller_information      122 non-null    object
#  20  variations              122 non-null    object
#  21  best_offer              122 non-null    str
#  22  more_offers             122 non-null    str
#  23  category                122 non-null    str
# dtypes: float64(3), int64(2), object(5), str(14)
# memory usage: 566.4+ KB

# %%
import random
df_filled['quantity'] = [random.randint(1,10) for i in range(len(df_filled))]
df_filled['Total_amount'] = df_filled['final_price'] * df_filled['quantity']
df_filled
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       0.0  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                    0
# 1                                                    0
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                    0
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                    0
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                    0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                    0
# 121  Fla███o 6███jay█████████s, ███████████████████...                    0
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category quantity  \
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops        7
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops        8
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# ..                                                 ...      ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops        8
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops        6
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops        4
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops        5
#
#                                           Total_amount
# 0    "₹599.00""₹599.00""₹599.00""₹599.00""₹599.00""...
# 1                                            "₹699.00"
# 2                                            "₹475.00"
# 3    "₹732.00""₹732.00""₹732.00""₹732.00""₹732.00""...
# 4                                            "₹431.00"
# ..                                                 ...
# 117                                        "₹2,495.00"
# 118  "₹732.00""₹732.00""₹732.00""₹732.00""₹732.00""...
# 119  "₹479.00""₹479.00""₹479.00""₹479.00""₹479.00""...
# 120               "₹449.00""₹449.00""₹449.00""₹449.00"
# 121      "₹631.00""₹631.00""₹631.00""₹631.00""₹631.00"
#
# [122 rows x 26 columns]

# %%
df_filled.to_csv('Cleaned.csv',index=False)

# %%
df2 = pd.read_csv('Cleaned.csv')
df2
# Out:
#      product_id            title  \
# 0      18614510         Oxolloxo
# 1      18972586          MALHAAR
# 2      18937628  her by invictus
# 3      18972622          MALHAAR
# 4      18979466       KiddoPanti
# ..          ...              ...
# 117    18962100             Nike
# 118    18972666          MALHAAR
# 119    13748756           Madame
# 120    22568668           V-Mart
# 121    19297208         Friskers
#
#                                    product_description  rating  ratings_count  \
# 0                    Women Blue Crepe Blouson Crop Top     0.0              0
# 1    Yellow & Red Geometric Print Mandarin Collar C...     0.0              0
# 2                                   Printed A-Line Top     4.2             29
# 3                                 Green Print Wrap Top     0.0              0
# 4    White & Navy Blue Geometric Print Georgette Sh...     0.0              0
# ..                                                 ...     ...            ...
# 117         Women Black Brand Logo Printed Dri Fit Top     4.4             72
# 118                              Yellow Print Wrap Top     0.0              0
# 119              Women Peach-Coloured Self Checked Top     3.6             35
# 120      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
# 121          Women Black Solid Organic Cotton Tank Top     0.0              0
#
#      initial_price  discount  final_price currency  \
# 0           2299.0      73.0    "₹599.00"      INR
# 1           3329.0      79.0    "₹699.00"      INR
# 2           1398.0      66.0    "₹475.00"      INR
# 3           3329.0      78.0    "₹732.00"      INR
# 4            799.0      46.0    "₹431.00"      INR
# ..             ...       ...          ...      ...
# 117         2495.0       0.0  "₹2,495.00"      INR
# 118         3329.0      78.0    "₹732.00"      INR
# 119         1599.0      70.0    "₹479.00"      INR
# 120          449.0       0.0    "₹449.00"      INR
# 121         1578.0      60.0    "₹631.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/186...  ...
# 1    http://assets.myntassets.com/assets/images/189...  ...
# 2    http://assets.myntassets.com/assets/images/189...  ...
# 3    http://assets.myntassets.com/assets/images/189...  ...
# 4    http://assets.myntassets.com/assets/images/189...  ...
# ..                                                 ...  ...
# 117  http://assets.myntassets.com/assets/images/189...  ...
# 118  http://assets.myntassets.com/assets/images/189...  ...
# 119  http://assets.myntassets.com/assets/images/137...  ...
# 120  http://assets.myntassets.com/assets/images/225...  ...
# 121  http://assets.myntassets.com/assets/images/192...  ...
#
#                                     seller_name  \
# 0    M/S███PA ███ARE█████████E L███████████████
# 1                         BED███E S███IES██████
# 2                                  Sup███om ███
# 3                         BED███E S███IES██████
# 4             Kri███n A███rel█████████Lim██████
# ..                                          ...
# 117                  Nik███ndi███riv█████████ed
# 118                       BED███E S███IES██████
# 119                  JAI███MAR███OTH█████████TD
# 120                    V-M███ Re███l L█████████
# 121                                      Fly███
#
#                                                  sizes  \
# 0    [{"size":"S","value":"34.0in","value_name":"To...
# 1    [{"size":"S","value":"35.0in","value_name":"To...
# 2    [{"size":"S","value":"34.0in","value_name":"To...
# 3    [{"size":"XS","value":"33.0in","value_name":"T...
# 4    [{"size":"2-3Y","value":"14.8in","value_name":...
# ..                                                 ...
# 117  [{"size":"XS","value":"34.25in","value_name":"...
# 118  [{"size":"XS","value":"33.0in","value_name":"T...
# 119  [{"size":"S","value":"34.0in","value_name":"Bu...
# 120  [{"size":"S","value":"25.0in","value_name":"Fr...
# 121  [{"size":"XS","value":"28.0in","value_name":"B...
#
#                                                 videos  \
# 0                                                    0
# 1                                                    0
# 2    ["rw-18937628_cae700","https://videos.myntasse...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 117                             ["rw-18962100_cae700"]
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#                                     seller_information           variations  \
# 0    C-1███ 1S███LOO█████████3No███████████████████...                 [{}]
# 1    1/4███Rii███Ind█████████rea███████████████████...  [{},{},{},{},{},{}]
# 2    Plo███o- ███ 1s█████████Sui███████████████████...                    0
# 3    1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 4    Gro███ Fl███, 4█████████n A███████████████████...              [{},{}]
# ..                                                 ...                  ...
# 117  Oly███a B███din█████████e T███████████████████...                    0
# 118  1/4███Rii███Ind█████████rea███████████████████...           [{},{},{}]
# 119  CIN███520███200█████████0 #███████████████████...                    0
# 120  Plo███o.8███ Se█████████Pha███████████████████...                    0
# 121  Fla███o 6███jay█████████s, ███████████████████...                    0
#
#                                             best_offer  \
# 0    {"applicable_on":"Orders above Rs. 649 (only o...
# 1    {"applicable_on":"Orders above Rs. 999 (only o...
# 2    {"applicable_on":"Orders above Rs. 649 (only o...
# 3    {"applicable_on":"Orders above Rs. 999 (only o...
# 4    {"applicable_on":"Orders above Rs. 649 (only o...
# ..                                                 ...
# 117  {"applicable_on":"Orders above Rs. 1499 (only ...
# 118  {"applicable_on":"Orders above Rs. 999 (only o...
# 119  {"applicable_on":"Orders above Rs. 649 (only o...
# 120  {"applicable_on":"Orders above Rs. 649 (only o...
# 121  {"applicable_on":"Orders above Rs. 649 (only o...
#
#                                            more_offers category quantity  \
# 0    [{"offer_name":"10% Instant Discount on IndusI...     tops        7
# 1    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 2    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 3    [{"offer_name":"10% Instant Discount on IndusI...     tops        8
# 4    [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# ..                                                 ...      ...      ...
# 117  [{"offer_name":"10% Instant Discount on IndusI...     tops        1
# 118  [{"offer_name":"10% Instant Discount on IndusI...     tops        8
# 119  [{"offer_name":"10% Instant Discount on IndusI...     tops        6
# 120  [{"offer_name":"10% Instant Discount on IndusI...     tops        4
# 121  [{"offer_name":"10% Instant Discount on IndusI...     tops        5
#
#                                           Total_amount
# 0    "₹599.00""₹599.00""₹599.00""₹599.00""₹599.00""...
# 1                                            "₹699.00"
# 2                                            "₹475.00"
# 3    "₹732.00""₹732.00""₹732.00""₹732.00""₹732.00""...
# 4                                            "₹431.00"
# ..                                                 ...
# 117                                        "₹2,495.00"
# 118  "₹732.00""₹732.00""₹732.00""₹732.00""₹732.00""...
# 119  "₹479.00""₹479.00""₹479.00""₹479.00""₹479.00""...
# 120               "₹449.00""₹449.00""₹449.00""₹449.00"
# 121      "₹631.00""₹631.00""₹631.00""₹631.00""₹631.00"
#
# [122 rows x 26 columns]

# %% [markdown]
# ## Summary
#
# * In this assignment, we used the `tops.csv` dataset provided through the Kaggle resource.
# * We loaded the CSV dataset using Pandas.
# * After loading the dataset, we explored the data using built-in Pandas functions such as `describe()`, `info()`, `head()`, and `tail()`.
# * We checked the dataset for missing (null) values in the DataFrame.
# * The missing values were handled using the `fillna()` function in Pandas.
# * We also checked for duplicate records and removed duplicate rows from the dataset.
# * A new column named `Total_amount` was created using the `final_price` and `quantity` columns from the DataFrame.
#
#     Total_amount = final_price x quantity
# * Finally, the cleaned dataset was saved as a new CSV output file.
